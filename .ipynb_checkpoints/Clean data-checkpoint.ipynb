# %% [markdown]
# Mounting my Google Drive in order to access the data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
pathFiles = '/content/drive/My Drive/soleadify_sample_data/'

# %% [markdown]
# Reading the first line from the website dataset to understand the structure

# %%
with open(pathFiles+'website dataset.csv', 'r') as f:
  line = f.readline()

print(line)
# Out:
# root_domain,domain_suffix,language,legal_name,main_city,main_country,main_region,phone,site_name,tld,s_category,,,,,,

# %% [markdown]
# Seems like there are several columns at the end that do not contain any sort of information. I will try to read the whole dataset and if these columns do not contain anything I will discard them.

# %%
website_dataset = pd.read_csv(pathFiles+'website dataset.csv')
website_dataset.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (12,14,15,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#            root_domain domain_suffix  ... Unnamed: 15 Unnamed: 16
# 0     converterman.com           NaN  ...         NaN         NaN
# 1  clothesencounter.ca            ca  ...         NaN         NaN
# 2       investa.com.au        com.au  ...         NaN         NaN
# 3    timminsgarage.com           com  ...         NaN         NaN
# 4         destinate.ca            ca  ...         NaN         NaN
#
# [5 rows x 17 columns]

# %%
website_dataset.columns
# Out:
# Index(['root_domain', 'domain_suffix', 'language', 'legal_name', 'main_city',
#        'main_country', 'main_region', 'phone', 'site_name', 'tld',
#        's_category', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16'],
#       dtype='object')

# %%
columns = ['Unnamed: '+str(i) for i in range(11,17)]
print('Website dataset has',website_dataset.shape, 'rows')
extra_columns = website_dataset[columns].apply(lambda col: col.notna()).sum()
print('In the unnamed columns we have the following number of records which are not null')
extra_columns
# Out:
# Website dataset has (71917, 17) rows
# In the unnamed columns we have the following number of records which are not null
# Unnamed: 11    8
# Unnamed: 12    3
# Unnamed: 13    2
# Unnamed: 14    2
# Unnamed: 15    2
# Unnamed: 16    2
# dtype: int64

# %% [markdown]
# Seems like the last 6 columns do not have a name nor do they contain any sort of information. Therefore I will discard them as they do not bring value.

# %%
columns_to_include = [x for x in range(11)]
website_dataset = pd.read_csv(pathFiles+'website dataset.csv', usecols = columns_to_include)

# %%
website_dataset.head(10)
# Out:
#             root_domain domain_suffix  ...  tld                           s_category
# 0      converterman.com           NaN  ...  NaN                                  NaN
# 1   clothesencounter.ca            ca  ...   ca        Shoes & Other Footwear Stores
# 2        investa.com.au        com.au  ...   au               Real Estate Developers
# 3     timminsgarage.com           com  ...  com   Automobile Dealers & Manufacturers
# 4          destinate.ca            ca  ...   ca                  Business Consulting
# 5           ironcrow.ca            ca  ...   ca                     Furniture Stores
# 6     springboarddm.com           com  ...  com                       Data Solutions
# 7  stoneandtilesrus.com           com  ...  com                           Tile Store
# 8          mdaccpap.com           com  ...  com         Medical Supply Manufacturers
# 9           micacchi.ca            ca  ...   ca  Architects & Architectural Services
#
# [10 rows x 11 columns]

# %%
google_dataset = pd.read_csv(pathFiles+'google dataset.csv')
google_dataset.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-16-dbdb45e6892b> in <module>()
# ----> 1 google_dataset = pd.read_csv(pathFiles+'google dataset.csv')
#       2 google_dataset.head()
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     458
#     459     try:
# --> 460         data = parser.read(nrows)
#     461     finally:
#     462         parser.close()
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read(self, nrows)
#    1196     def read(self, nrows=None):
#    1197         nrows = _validate_integer("nrows", nrows)
# -> 1198         ret = self._engine.read(nrows)
#    1199
#    1200         # May alter columns / col_dict
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read(self, nrows)
#    2155     def read(self, nrows=None):
#    2156         try:
# -> 2157             data = self._reader.read(nrows)
#    2158         except StopIteration:
#    2159             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 15 fields in line 18, saw 16

# %% [markdown]
# It seems that Line 18 of the google dataset has more fields than expecting. I will read 1 line from the beginning and line 18 to compare them. Then I will decide on the approach

# %%
with open(pathFiles+'google dataset.csv') as f:
  for index, line in enumerate(f):
    if index == 0:
      header = line
    elif index == 1:
      line_1 = line
    elif index == 18:
      line_18 = line
    elif index>18:
      break
print(header)
print(line_1)
print(line_18)
# Out:
# address,category,city,country_code,country_name,name,phone,phone_country_code,raw_address,raw_phone,region_code,region_name,text,zip_code,domain
#
# "28 Central Coast Hwy, West Gosford NSW 2250, Australia",Fabric-Based Home Goods,gosford,au,australia,Spotlight West Gosford,+61243355946,au,"West Gosford NSW, Australia",+61 2 4335 5946,nsw,new south wales,"4.1 (766) · Craft store West Gosford NSW, Australia Closed ⋅ Opens 9AM Sun · +61 2 4335 5946 In-store pickup·In-store shopping",2250,spotlightstores.com
#
# "363 Horton St E, London, ON N6B 1L6, Canada",Beauty Salons - Equipment & Supplies,london,"",canada,Halo Hair Co,"","",363 Horton St E,"",on,ontario,"4.7 (3) · Hairdresser 363 Horton St E Closed ⋅ Opens 10AM Tue \"Loved the energy and the vibe in the salon.. and love my hair!!!\"",n6b 1l6,instagram.com

# %%
google_dataset = pd.read_csv(pathFiles+'google dataset.csv', quotechar='"', escapechar='\\')

# %%
google_dataset.head(10)
# Out:
#                                              address  ...               domain
# 0  28 Central Coast Hwy, West Gosford NSW 2250, A...  ...  spotlightstores.com
# 1   400 Scott St, St. Catharines, ON L2M 3W2, Canada  ...      bookmanager.com
# 2      191 Pleasant St, Yarmouth, NS B5A 2J9, Canada  ...        timbermart.ca
# 3  11040 Santa Monica Blvd Suite 370, Los Angeles...  ...            linktr.ee
# 4                                                NaN  ...            linktr.ee
# 5                        Ferndale, MI, United States  ...            linktr.ee
# 6            321 Kent St, Sydney NSW 2000, Australia  ...     icare.nsw.gov.au
# 7          55 S Cleveland Ave, Westerville, OH 43081  ...       kindercare.com
# 8  4050 S Torrey Pines Dr, Las Vegas, NV 89103, U...  ...       kindercare.com
# 9  7+ years in business · St Paul, MN, United States  ...       kindercare.com
#
# [10 rows x 15 columns]

# %% [markdown]
# Seems like adding an escape char worked, google data has been read.

# %%
facebook_dataset = pd.read_csv(pathFiles+'facebook dataset.csv', quotechar='"', escapechar='\\')

# %%
facebook_dataset.head(10)
# Out:
#                     domain  ... zip_code
# 0       euro-hygiene-34.fr  ...    30420
# 1  lakesidehomeservices.ca  ...      NaN
# 2        rossiterboats.com  ...      NaN
# 3     caa-architecture.com  ...  v6b 1g1
# 4            apexsurety.ca  ...  r3l 2t7
# 5           collins-cc.edu  ...      NaN
# 6          dovercheese.com  ...  n0a 1n0
# 7       alphascientific.ca  ...  v6p 5a2
# 8           modernmama.com  ...      NaN
# 9         unitysodfarm.com  ...      NaN
#
# [10 rows x 16 columns]

# %% [markdown]
# I will next evaluate the information available in the 3 datasets:
# *   what columns are in each dataset?
#     - which are common? -> could be used as linkage keys
#     - which are unique -> useful to expand the information available
# *   how many companies are in each dataset?
#     - if there is no overlap then in total I should have the sum of rows of the 3 datasets
#     - there should be at least some form of overlapping -> how do I evaluate how much data I have to discard due to linkaged mismatch?

# %%
print('Website columns', website_dataset.columns)
print('Google columns', google_dataset.columns)
print('Facebook columns', facebook_dataset.columns)
# Out:
# Website columns Index(['root_domain', 'domain_suffix', 'language', 'legal_name', 'main_city',
#        'main_country', 'main_region', 'phone', 'site_name', 'tld',
#        's_category'],
#       dtype='object')
# Google columns Index(['address', 'category', 'city', 'country_code', 'country_name', 'name',
#        'phone', 'phone_country_code', 'raw_address', 'raw_phone',
#        'region_code', 'region_name', 'text', 'zip_code', 'domain'],
#       dtype='object')
# Facebook columns Index(['domain', 'address', 'categories', 'city', 'country_code',
#        'country_name', 'description', 'email', 'link', 'name', 'page_type',
#        'phone', 'phone_country_code', 'region_code', 'region_name',
#        'zip_code'],
#       dtype='object')

# %% [markdown]
# It looks that there are a lot of columns that are common. However it seems that the same column is slightly different in each dataset.
#
# I will divide the columns into several clusters:
# Cluster 1 - Columns which can be used to split the datasets into smaller chuks which can be easier to link. For example it should be easier to link Insurance companies from USA, New York across the 3 datasets, than linking everything using all columns. The matching algorithm will have to work on a smaller set -> probably better results and performance.
#
# Here I include geographical information such as
# *   City
#     - Websiste -> called main_city
#     - Google -> called city
#     - Facebook -> called city
# *   Country
#     - Website -> called main_country
#     - Google -> called country_name
#     - Facebook -> called country_name
# *    Region
#     - Website -> called main_region
#     - Google -> called region_name; also available region_code
#     - Facebook -> called region_name; also available region_code
#
# On top of that between Google and Facebook datasets there seems to be also the Zip Code which is common and could be used to further narrow down the matching. Between these 2 it seems that we also have some form of address field in both datasets. Could be useful as well.
#
# Also the category could be useful. Howver across the 3 datasets this field seems to store slightly different information.
# *   Category
#     - Website -> called s_category -> this seems to include only top level information such as "Business Consulting", "Furniture Store"
#     - Google -> called category -> this seems to include only top level information such as "Book Stores", "Catering & Delivery"
#     - Facebook -> called categories. It seems to be a much more detailed Category Tree such as
#
# Cluster 2 - Columns which can be used to uniquely identify a company. They could be used individually or combined.
#
#
# *   Domain
#     - Website -> called root_domain
#     - Google -> called domain
#     - Facebook -> called domain
# *   Company name
#     - Website -> 2 fields: site_name, legal_name
#     - Google -> called name
#     - Facebook -> called name
# *   Phone
#     - Websiste -> called phone. It seems to be a number stored as string, however it does not include the + as part of the dialing code.
#     - Google -> 2 fields: phone, string as number, raw_phone, string which includes the dialing code
#     - Facebook -> phone, string as number
#
# Between Google and Facebook there is also the phone_country_code which is common and could be used together with the Geographical information to match the data. Besides this, the address field is also common. However it seems that the address field is slightly different. It will need more investigation before using it
#
# Finally there is a set of information which is unique to a dataset:
#
#
# *   Website: legal_name, language and tld (top-level domain). Out of these 3, the legal_name is rather unique and possibly expanding the information available. Language and tld don't seem to be that useful.
# *   Google: text. It seems to be a combination of address, Google Rating and something else.
# *   Facebook: description, email, link, page_type. Out of these, the link is the least useful information. It is to some extent already included in the domain. Protocol is however not included here. Email, description are extremly useful and unique. Page Type can also be useful, but it's mainly subject to the definition used by Facebook.

# %%
print('Website dataset has {0:,} rows'.format(website_dataset.shape[0]))
print('Google dataset has {0:,} rows'.format(google_dataset.shape[0]))
print('Facebook dataset has {0:,} rows'.format(facebook_dataset.shape[0]))
# Out:
# Website dataset has 71,917 rows
# Google dataset has 356,520 rows
# Facebook dataset has 72,010 rows

# %% [markdown]
# Based on the analysis of common columns and number of rows, the high level strategy will be to
# Step 1: Link Google and Facebook data into a single dataset
# Step 2: Link the combined dataset with the Website dataset
#
# Reason for this approach is:
# *   Google and Facebook have a few more columns in common. To be investigated to what extent this columns actually have data and how information is structured in them.
# *   Google is the dataset with the most rows. Standalone it has the most value. The other 2 datasets have only 20% of the number of rows. Therefore at best they could: either increase the dataset with 20% more rows (union - no common rows) or increase the information available for 20% of the Google dataset (join - all rows are in common).

# %% [markdown]
# Next step is to explore the quality of each dataset:
# *    How many missing values in each column?
# *    Are the countries / regions consistent or are there variations - UPPERCASE, lowercase, Titlecase etc.
# *    Are there duplicates?

# %%
website_dataset.describe()
# Out:
#            root_domain  ...                                        s_category
# count            71917  ...                                             70677
# unique           71917  ...                                               568
# top     bbqgourmet.com  ...  Executive, Legislative & Government Institutions
# freq                 1  ...                                              1508
#
# [4 rows x 11 columns]

# %% [markdown]
# Based on the output above:
# *    root_domain can be used to uniquely identify a row. Count is equal to Unique therefore no duplicates.
# *    legal_name - count is higher than unique. This means that some root_domains are associated to the same legal_names. There are duplicates in this column
# *    site_name seems to cover more of the data than legal_name. However the degree of duplication is higher.
# *    unique country count is 253. There are only 195 countries in the world -> there is duplication also in the form of inconsistent writing of the same information.
# *    phone - unique is lower than count. Again a case of duplication

# %%
# I want to check that the root_domain is truly unique or actually duplication exists, it's just hidden by Case variation
(website_dataset['root_domain'].apply(lambda x: (x.lower()).strip())).describe()
# It seems that is indeed unique, that is good
# Out:
# count              71917
# unique             71917
# top       bbqgourmet.com
# freq                   1
# Name: root_domain, dtype: object

# %%
site_names_raw = website_dataset.groupby('site_name')['root_domain'].count().sort_values(ascending = False)
print(site_names_raw.head(30))
# Based on this output I'm going to apply some cleaning on this column
import numpy as np
replacements = ['Mysite','mysite', 'My Site','Home', 'website', '#NAME?']
website_dataset['site_name_clean']=website_dataset['site_name'].replace(replacements, [np.nan] * len(replacements)).str.strip()

site_names_cleaned = website_dataset.groupby('site_name_clean')['root_domain'].count().sort_values(ascending = False)
print(site_names_cleaned.head(30))
print(site_names_cleaned.tail(30))
# Out:
# site_name
# Mysite                                  40
# mysite                                  29
# The Canadian Real Estate                27
# Home                                    24
# InMotion Hosting                        16
# InterWorx                               15
# Desjardins Insurance                    15
# website                                 14
# #NAME?                                  10
# SchoolMessenger                         10
# Royal LePage                             8
# TCS                                      8
# Hosting                                  8
# Net Driven                               8
# NodeWorx                                 8
# Website.com Solutions                    8
# ShopCity.com                             8
# CFA                                      7
# Standard Auto Glass                      7
# Red Deer                                 7
# Garaga                                   7
# AMVOQ                                    7
# Hilti                                    6
# Unilever                                 6
# Skyward                                  6
# The Salvation Army                       6
# Directwest                               6
# The Canadian Real Estate Association     6
# CCA                                      6
# Philips                                  5
# Name: root_domain, dtype: int64
# site_name_clean
# The Canadian Real Estate                27
# InMotion Hosting                        16
# InterWorx                               15
# Desjardins Insurance                    15
# SchoolMessenger                         10
# NodeWorx                                 8
# Net Driven                               8
# Royal LePage                             8
# Website.com Solutions                    8
# TCS                                      8
# Hosting                                  8
# ShopCity.com                             8
# CFA                                      7
# Standard Auto Glass                      7
# Garaga                                   7
# Red Deer                                 7
# AMVOQ                                    7
# Unilever                                 6
# CCA                                      6
# Hilti                                    6
# Skyward                                  6
# The Canadian Real Estate Association     6
# Directwest                               6
# The Salvation Army                       6
# Philips                                  5
# Airbnb                                   5
# Vodafone                                 5
# KONE                                     5
# Intel                                    5
# TAS                                      5
# Name: root_domain, dtype: int64
# site_name_clean
# Pipestone Area Chamber of Commerce    1
# Pirogovskogo Tsentra                  1
# Pirie Appliances                      1
# Piri Reis Universitesi                1
# Pirate Blue                           1
# Piranhaconcretesawing                 1
# Piramid Mfg                           1
# Piramal Realty                        1
# Piramal Group                         1
# Pips Clean Team                       1
# Pippa Deeley Auctions                 1
# Pipestone Projects                    1
# Pipestone Lodge                       1
# Pipestone Area Schools                1
# Pipes Plumbing Services               1
# Pioneer Fire Protection District      1
# Piped Up Plumbing                     1
# Piotrowski                            1
# Piorra Maison                         1
# Pioner Cinema                         1
# Pioneerland Webmail                   1
# Pioneer Window & Door                 1
# Pioneer State High School             1
# Pioneer School District               1
# Pioneer Paving                        1
# Pioneer Iron Works.                   1
# Pioneer Homes                         1
# Pioneer Heavy Haul                    1
# Pioneer Flower Farms                  1
# #9 Auto Sales                         1
# Name: root_domain, dtype: int64

# %%
categories_raw = website_dataset.groupby('s_category')['root_domain'].count().sort_values(ascending = False)
print(categories_raw.head(30))
print(categories_raw.tail(30))

# Based on the output there are a few instances that can be replaced and also some case incosistency
replacements = ['com','org', 'ru']
website_dataset['category_clean']=(website_dataset['s_category'].replace(replacements, [np.nan] * len(replacements)).str.strip()).str.title()

categories_cleaned = website_dataset.groupby('category_clean')['root_domain'].count().sort_values(ascending = False)
print(categories_cleaned.head(30))
print(categories_cleaned.tail(30))
# Out:
# s_category
# Executive, Legislative & Government Institutions    1508
# Colleges & Universities                             1323
# High Schools                                        1277
# Home Builders & Renovation Contractors               919
# Automobile Dealers & Manufacturers                   873
# Parked Domains                                       785
# Auto Services                                        756
# Tech Companies                                       753
# Real Estate - Agents & Managers                      738
# Bakeries & Desserts                                  686
# Commercial Printing                                  674
# Landscaping & Lawn Services                          653
# Churches & Religious Organizations                   632
# Yoga Studios                                         629
# Heating & Air Conditioning                           601
# Oil & Gas - Extraction & Distribution                561
# Social Services & NGOs                               508
# Employment Agencies & HR Consulting                  487
# Electrical & Wiring Contractors                      430
# Hair Salons                                          425
# Restaurants                                          414
# Accounting & Bookkeeping Services                    413
# Windows & Door Shops                                 409
# Dance Schools                                        408
# Clinics - Surgeons & Physicians                      407
# Decorators & Interior Designers                      405
# Libraries                                            404
# Newspapers & Magazines                               401
# Trucking and Logistics                               395
# Architects & Architectural Services                  389
# Name: root_domain, dtype: int64
# s_category
# Comedy Club                              11
# Watch Repair Shop                        10
# Domestic Violence NGOs                   10
# Title Abstract & Settlement Offices       9
# Gastroenterology Clinics                  9
# Media & Telecom Associations              9
# Abortion Clinics                          8
# Allergists                                8
# Fur Goods                                 8
# Adult Entertainment Clubs                 7
# Forging & Metal Stampings                 7
# Estate Planning & Elder Law Attorneys     7
# Boys & Girls Clubs                        7
# Urology Clinics                           6
# Bail Bonds                                6
# Endodontists                              6
# Skydiving Center                          6
# YMCA Camps                                6
# Haunted Houses                            5
# Sex Shops                                 4
# Glaziers & Glass Contractors              3
# Escrow Companies                          2
# com                                       2
# org                                       2
# Scout Camps                               2
# Veterinary Associations                   1
# ru                                        1
# Uralkali                                  1
# mesquite                                  1
# wilmington                                1
# Name: root_domain, dtype: int64
# category_clean
# Executive, Legislative & Government Institutions    1508
# Colleges & Universities                             1323
# High Schools                                        1277
# Home Builders & Renovation Contractors               919
# Automobile Dealers & Manufacturers                   873
# Parked Domains                                       785
# Auto Services                                        756
# Tech Companies                                       753
# Real Estate - Agents & Managers                      738
# Bakeries & Desserts                                  686
# Commercial Printing                                  674
# Landscaping & Lawn Services                          653
# Churches & Religious Organizations                   632
# Yoga Studios                                         629
# Heating & Air Conditioning                           601
# Oil & Gas - Extraction & Distribution                561
# Social Services & Ngos                               508
# Employment Agencies & Hr Consulting                  487
# Electrical & Wiring Contractors                      430
# Hair Salons                                          425
# Restaurants                                          414
# Accounting & Bookkeeping Services                    413
# Windows & Door Shops                                 409
# Dance Schools                                        408
# Clinics - Surgeons & Physicians                      407
# Decorators & Interior Designers                      405
# Libraries                                            404
# Newspapers & Magazines                               401
# Trucking And Logistics                               395
# Architects & Architectural Services                  389
# Name: root_domain, dtype: int64
# category_clean
# Nephrology Clinic                        11
# Entertainers                             11
# Comedy Club                              11
# Cardiology Clinics                       11
# Watch Repair Shop                        10
# Domestic Violence Ngos                   10
# Title Abstract & Settlement Offices       9
# Media & Telecom Associations              9
# Gastroenterology Clinics                  9
# Fur Goods                                 8
# Abortion Clinics                          8
# Allergists                                8
# Adult Entertainment Clubs                 7
# Boys & Girls Clubs                        7
# Estate Planning & Elder Law Attorneys     7
# Forging & Metal Stampings                 7
# Endodontists                              6
# Ymca Camps                                6
# Skydiving Center                          6
# Bail Bonds                                6
# Urology Clinics                           6
# Haunted Houses                            5
# Sex Shops                                 4
# Glaziers & Glass Contractors              3
# Escrow Companies                          2
# Scout Camps                               2
# Veterinary Associations                   1
# Uralkali                                  1
# Wilmington                                1
# Mesquite                                  1
# Name: root_domain, dtype: int64

# %%
legal_names_raw = website_dataset.groupby('legal_name')['root_domain'].count().sort_values(ascending = False)
print(legal_names_raw.head(60))
print(legal_names_raw.tail(60))

# Several action points - strings Inc. INC represent the same thing, company type
# -> All uppercase could solve the problem combined with a removal of the . at the end
# Strings- , Inc is the same as Inc
# -> Replacing the , with an empty characther should solve it
# Ltd and Limited are the same thing. Inc and Incorporated are the same thing
# Corporation, Corp are the same thing

def clean_legal_name(legal_name):
  if not pd.isna(legal_name):
    out = legal_name.rstrip(' .').replace(',','').upper()

    if out.find('LIMITED')>-1:
      out = out.replace('LIMITED','LTD')
    elif out.find('INCORPORATED')>-1:
      out = out.replace('INCORPORATED','INC')
    elif out.find('CORPORATION')>-1:
      out = out.replace('CORPORATION','CORP')
  else:
      out = legal_name
  
  return out


website_dataset['legal_name_clean'] = website_dataset['legal_name'].apply(clean_legal_name)

legal_names_cleaned = website_dataset.groupby('legal_name_clean')['root_domain'].count().sort_values(ascending = False)
print(legal_names_cleaned.head(60))
print(legal_names_cleaned.tail(60))
# Out:
# legal_name
# Blackboard, Inc.                                  211
# LifeLearn Animal Health (LifeLearn Inc.)           52
# Dealer Spike, LLC                                  50
# REALTOR(r) Canada Inc.                             31
# Desjardins Financial Security Investments Inc.     27
# TouchBistro Inc.                                   27
# Google, Inc.                                       26
# FCA Canada Inc.                                    22
# Google Inc.                                        21
# PowerSchool Group LLC                              21
# MH Sub I, LLC                                      21
# General Motors of Canada Company                   17
# Harvest Digital Planning Pty Ltd                   16
# Lovingly, LLC                                      13
# Innovative Interfaces, Inc.                        12
# Apple Inc.                                         11
# Dominion Lending Centres Inc.                      11
# Google LLC                                         11
# Facebook Inc.                                      10
# Goodyear Canada Inc.                               10
# Consolidated Funeral Services, Inc.                 9
# Hetzner Online GmbH                                 9
# DeSales Media Group, Inc.                           8
# ShopCity.com, Inc.                                  8
# SportsEngine, Inc.                                  8
# Schoolwires, Inc.                                   8
# Rural Press Pty Ltd                                 8
# Wheels Manufacturing Inc.                           8
# ARI Network Services Inc.                           8
# SHNIER, Gesco Limited Partnership                   7
# Ford Motor Company                                  7
# Bang the Table Pty Ltd                              7
# Garaga Inc.                                         7
# BiteBank Websites Inc.                              7
# Nissan Canada Inc.                                  7
# Ford Motor Company of Canada                        7
# WatchGuard Technologies, Inc.                       7
# Quadrus Investment Services Ltd.                    6
# B Corp                                              6
# Tiffany & Co.                                       6
# Jumptools(r) Inc.                                   6
# RIGHT AT HOME REALTY INC.                           6
# Adster Creative Inc.                                6
# Google Ireland Limited                              6
# XYZ Doohickey Company                               6
# Skenzo Ltd.                                         6
# Nationwide News Pty Ltd                             6
# Lovingly, LLC.                                      6
# SWsoft, Inc.                                        6
# Dude Solutions Inc.                                 5
# Red Deer, AB                                        5
# Follett School Solutions, Inc.                      5
# Facilisgroup LLP                                    5
# FundEX Investments Inc.                             5
# Envato Pty Ltd                                      5
# Eagers Automotive Limited                           5
# Blackboard Inc.                                     5
# Koninklijke Philips N.V.                            5
# MediaNews Group, Inc.                               4
# AM Royalties Limited Partnership                    4
# Name: root_domain, dtype: int64
# legal_name
# PAVE Schools, Inc.                                               1
# PBBnz Ltd                                                        1
# PHOEAPOLIS ORGANICS INC.                                         1
# PETROVIETNAM OIL CORPORATION                                     1
# PECASO GROUP INC.                                                1
# PEER Bearing Company                                             1
# PEI Berries Ltd.                                                 1
# PEI Business Federation Ltd                                      1
# PEI Juice Works Ltd.                                             1
# PELOSO LANDSCAPING INC.                                          1
# PEMS Consultants Group LLC                                       1
# PENLA GLOBAL LTD                                                 1
# PERFECT LEATHER GOODS LTD.                                       1
# PERITAE, INC.                                                    1
# PERMIT EXPERTS INC.                                              1
# PETIT NOTAIRE INC.                                               1
# PG Contracting, LLC                                              1
# PBI--Pioneer Boosters, Inc.                                      1
# PGA Experts inc.                                                 1
# PGG Wrightson Limited                                            1
# PGH Bricks & Pavers Pty Ltd                                      1
# PGSBPO Pte. Ltd.                                                 1
# PH GLOBAL JET EXPRESS INC.                                       1
# PHARMASERVICE S.A.                                               1
# PHASE 1 SYSTEMS CORPORATION                                      1
# PHC Holdings Corporation                                         1
# PHD Germany GmbH                                                 1
# PHD Inc                                                          1
# PHI Financial Services, Inc.                                     1
# PHILLYSEEDS, INC.                                                1
# PEC Property Sisters Inc.                                        1
# PEARL BRIDAL HOUSE INC.                                          1
# PEAK Smiles Inc.                                                 1
# PEAK SCAFFOLD LTD.                                               1
# PBR Laboratories Inc.                                            1
# PC COURT COMPAGNY LIMITED                                        1
# PC ChAZ LLC                                                      1
# PC Mechanical Services, Inc                                      1
# PC QUALITE TOITS INC                                             1
# PC Repair Depot Limited                                          1
# PCA Life Assurance Co., Ltd.                                     1
# PCA SERVICES CORPORATIFS INC                                     1
# PCCU Insurance Ltd.                                              1
# PCCW Global Limited                                              1
# PCCW Solutions Limited                                           1
# PCCW Teleservices (Philippines), Inc.                            1
# PCF HR Solutions Inc.                                            1
# PCI Agricultural Services (Pty) Ltd                              1
# PCL Constructors Canada Inc.                                     1
# PCL Graphics Ltd.                                                1
# PCM Corp                                                         1
# PD Autotechs Ltd.                                                1
# PDE Ltd.                                                         1
# PDR Hail Team Inc.                                               1
# PE Capital Funds Management Ltd                                  1
# PEACE COUNTRY FILTRATION LTD                                     1
# PEACH JAM RECORDS INC.                                           1
# PEAK Benefit Solutions Inc.                                      1
# PEAK HOMES LTD.                                                  1
# #1 IT Support & Services Company in Winnipeg | Avenir IT Inc.    1
# Name: root_domain, dtype: int64
# legal_name_clean
# BLACKBOARD INC                                   216
# LIFELEARN ANIMAL HEALTH (LIFELEARN INC.)          52
# DEALER SPIKE LLC                                  50
# GOOGLE INC                                        47
# REALTOR(R) CANADA INC                             31
# DESJARDINS FINANCIAL SECURITY INVESTMENTS INC     27
# TOUCHBISTRO INC                                   27
# FCA CANADA INC                                    22
# POWERSCHOOL GROUP LLC                             21
# MH SUB I LLC                                      21
# LOVINGLY LLC                                      19
# GENERAL MOTORS OF CANADA COMPANY                  17
# HARVEST DIGITAL PLANNING PTY LTD                  16
# FACEBOOK INC                                      13
# INNOVATIVE INTERFACES INC                         12
# GOODYEAR CANADA INC                               11
# GOOGLE LLC                                        11
# DOMINION LENDING CENTRES INC                      11
# APPLE INC                                         11
# HETZNER ONLINE GMBH                                9
# RIGHT AT HOME REALTY INC                           9
# RED DEER AB                                        9
# CONSOLIDATED FUNERAL SERVICES INC                  9
# RURAL PRESS PTY LTD                                8
# GARAGA INC                                         8
# GOOGLE IRELAND LTD                                 8
# SHOPCITY.COM INC                                   8
# WHEELS MANUFACTURING INC                           8
# SPORTSENGINE INC                                   8
# DESALES MEDIA GROUP INC                            8
# SCHOOLWIRES INC                                    8
# ARI NETWORK SERVICES INC                           8
# BITEBANK WEBSITES INC                              7
# NISSAN CANADA INC                                  7
# SHNIER GESCO LTD PARTNERSHIP                       7
# FORD MOTOR COMPANY                                 7
# FORD MOTOR COMPANY OF CANADA                       7
# B CORP                                             7
# NATIONWIDE NEWS PTY LTD                            7
# BANG THE TABLE PTY LTD                             7
# WATCHGUARD TECHNOLOGIES INC                        7
# QUADRUS INVESTMENT SERVICES LTD                    6
# TIFFANY & CO                                       6
# ADSTER CREATIVE INC                                6
# XYZ DOOHICKEY COMPANY                              6
# SWSOFT INC                                         6
# JUMPTOOLS(R) INC                                   6
# SKENZO LTD                                         6
# MEDICINE HAT AB                                    6
# REAL ESTATE PROFESSIONALS INC                      6
# FUNDEX INVESTMENTS INC                             5
# ENVATO PTY LTD                                     5
# RIFLE PAPER CO                                     5
# FOLLETT SCHOOL SOLUTIONS INC                       5
# EAGERS AUTOMOTIVE LTD                              5
# SIRIUS XM RADIO INC                                5
# FACILISGROUP LLP                                   5
# DUDE SOLUTIONS INC                                 5
# KONINKLIJKE PHILIPS N.V                            5
# MARKET MUSCLES LLC                                 4
# Name: root_domain, dtype: int64
# legal_name_clean
# ORACLE FISCALISTES INC                                                        1
# ORIGINAL TRADERS ENERGY LP                                                    1
# ORIGINALAB AB                                                                 1
# ORIGINALLUXURY INC                                                            1
# ORTHO-CLINICAL DIAGNOSTICS INC                                                1
# ORTHODONTIE SPÉCIALISÉE DE GATINEAU INC                                       1
# ORTHOGENIC LABORATORIES INC                                                   1
# ORTHOPEDICS AT YOUR STEP INC                                                  1
# OS SYSTEMS LTD                                                                1
# OSAT INC                                                                      1
# OSBORNE ACADEMY OF ACROBATICS INC                                             1
# OSC ACCESSIBILITY SPECIALISTS INC                                             1
# OSE COACHING IMMOBILIER INC                                                   1
# OSGOODE COMPANY                                                               1
# OSGOODE PHARMACY LTD                                                          1
# OSHAWA ART ASSOCIATION INC                                                    1
# OSHAWA HEARING AID CLINIC INC                                                 1
# OSHAWA PUC NETWORKS INC                                                       1
# OSHAWA TRAVEL LTD                                                             1
# OSILLA INSTITUTE FOR HEALTH PERSONNEL LTD                                     1
# OSIM INTERNATIONAL PTE. LTD                                                   1
# OSLC DEVELOPMENTS INC                                                         1
# OSLER HOSKIN & HARCOURT LLP                                                   1
# OSM ATLANTIQUE INC                                                            1
# OSMINGTON INC                                                                 1
# OSMOND LANGE ARCHITECTS SOUTH AFRICA (PTY) LTD                                1
# OSSINING VOLUNTEER AMBULANCE CORPS INC                                        1
# OSTEOPATHIE CONTINUUM INC                                                     1
# OSTEOPATHY CENTRE INC                                                         1
# OSTIM TEKNOLOJI A.S. OSTIM SPARE PARTS INC. OSTIM PROJE GELISIM A.S. OSTIM    1
# ORTHODONTIC BOUTIQUE INC                                                      1
# ORTHAUS CO                                                                    1
# ORIGINELLE INC                                                                1
# ORR INSURANCE BROKERS INC                                                     1
# ORIGO COMMUNICATIONS CORP                                                     1
# ORIOLE LANDSCAPING LTD                                                        1
# ORIOLE WINERY LTD                                                             1
# ORION ASSESSMENT SERVICES OF CANADA INC                                       1
# ORION AUDIT LTD                                                               1
# ORION CONTRACTING COMPANY                                                     1
# ORION FOOD RUS CO. LTD                                                        1
# ORION HEALTH GROUP LTD                                                        1
# ORION HOTELS & RESORTS (SOUTH AFRICA) (PTY) LTD                               1
# ORION REALTY CORP                                                             1
# ORION SOFTWARE INC                                                            1
# ORIX CORP                                                                     1
# ORJIN AUTOMOTIVE SAN.VE TIC. INC                                              1
# ORKOM ILETISIM HIZMETLERI LTD. STI                                            1
# ORLANDICE NGUYEN INTERIOR DESIGN LTD                                          1
# ORLEANS OPTOMETRY CLINIC INC                                                  1
# ORLEANS PRESTIGE GARDENS SHEDS INC                                            1
# ORLEANS SIGN INC                                                              1
# ORNAMENT TILES AND SURFACE LTD                                                1
# ORNAMENTS CANADA INC                                                          1
# OROMOCTO TRAINING & EMPLOYMENT CENTRE INC                                     1
# OROOJ FINANCIAL AND INSURANCE LTD                                             1
# ORORA PACKAGING AUSTRALIA PTY LTD                                             1
# ORP INC                                                                       1
# ORPHIUS TECHNOLOGIES PRIVATE LTD                                              1
# #1 IT SUPPORT & SERVICES COMPANY IN WINNIPEG | AVENIR IT INC                  1
# Name: root_domain, dtype: int64

# %%
countries_raw = website_dataset.groupby('main_country')['root_domain'].count().sort_values(ascending = False)
print(countries_raw.head(60))
print(countries_raw.tail(60))

#incosistent casing - Greece and greece, Taiwan and taiwan are the same thing

def clean_country(country):
  if not pd.isna(country):
    if country == ')"':
      return np.nan
    else:
      return country.strip().title()

website_dataset['country_clean'] = website_dataset['main_country'].apply(clean_country)

countries_cleaned = website_dataset.groupby('country_clean')['root_domain'].count().sort_values(ascending = False)
print(countries_cleaned.head(60))
print(countries_cleaned.tail(60))
# Out:
# main_country
# canada                  37628
# united states            9503
# australia                2482
# Canada                   2151
# united kingdom           1820
# turkey                    911
# russia                    698
# netherlands               624
# france                    609
# germany                   555
# south africa              539
# japan                     506
# united arab emirates      435
# malaysia                  428
# india                     405
# belgium                   377
# china                     255
# singapore                 232
# new zealand               225
# hong kong                 199
# Australia                 193
# spain                     177
# poland                    173
# greece                    162
# Greece                    159
# italy                     153
# Taiwan                    141
# taiwan                    135
# switzerland               110
# qatar                     106
# hungary                    94
# Turkey                     94
# philippines                88
# Japan                      87
# vietnam                    82
# Hong Kong                  79
# south korea                78
# Russia                     77
# mexico                     67
# norway                     67
# sweden                     57
# denmark                    57
# austria                    55
# brazil                     52
# thailand                   51
# South Africa               49
# South Korea                47
# Singapore                  46
# slovenia                   45
# portugal                   43
# oman                       42
# ireland                    41
# Poland                     40
# saudi arabia               39
# Malaysia                   39
# United Arab Emirates       37
# argentina                  35
# Belgium                    35
# indonesia                  34
# Netherlands                34
# Name: root_domain, dtype: int64
# main_country
# ulan-ude                             1
# Albania                              1
# Iraq                                 1
# sint maarten                         1
# vanuatu                              1
# El Salvador                          1
# Curaçao                              1
# Cyprus                               1
# Anguilla                             1
# Finland                              1
# Denmark                              1
# Kazakhstan                           1
# tajikistan                           1
# Guatemala                            1
# Antigua and Barbuda                  1
# Georgia                              1
# Brazil                               1
# solomon islands                      1
# french guiana                        1
# Kyrgyzstan                           1
# barbados                             1
# libya                                1
# bermuda                              1
# bhutan                               1
# laos                                 1
# bonaire, sint eustatius, and saba    1
# british virgin islands               1
# brunei                               1
# kosovo                               1
# burundi                              1
# cambodia                             1
# kenya                                1
# iceland                              1
# haiti                                1
# guam                                 1
# eureka                               1
# faroe islands                        1
# gabon                                1
# louisville                           1
# malawi                               1
# Madagascar                           1
# aruba                                1
# Malta                                1
# san marino                           1
# Niue                                 1
# papua new guinea                     1
# Republic of Lithuania                1
# palestine                            1
# Serbia                               1
# niger                                1
# Sweden                               1
# Switzerland                          1
# Tanzania                             1
# Tonga                                1
# Tunisia                              1
# Turks and Caicos Islands             1
# moscow                               1
# Venezuela                            1
# armenia                              1
# )"                                   1
# Name: root_domain, dtype: int64
# country_clean
# Canada                  39779
# United States            9524
# Australia                2675
# United Kingdom           1820
# Turkey                   1005
# Russia                    775
# Netherlands               658
# France                    615
# Japan                     593
# South Africa              588
# Germany                   577
# United Arab Emirates      472
# Malaysia                  467
# India                     431
# Belgium                   412
# Greece                    321
# Singapore                 278
# Hong Kong                 278
# Taiwan                    276
# China                     265
# New Zealand               231
# Poland                    213
# Spain                     184
# Italy                     158
# South Korea               125
# Qatar                     115
# Switzerland               111
# Hungary                    96
# Philippines                95
# Vietnam                    88
# Mexico                     75
# Norway                     67
# Thailand                   61
# Austria                    60
# Colombia                   59
# Sweden                     58
# Denmark                    58
# Brazil                     53
# Ireland                    46
# Oman                       45
# Slovenia                   45
# Portugal                   43
# Saudi Arabia               42
# Indonesia                  39
# Bangladesh                 39
# Argentina                  38
# Finland                    31
# Chile                      31
# Romania                    29
# Sri Lanka                  28
# Croatia                    24
# Czechia                    24
# Serbia                     24
# Peru                       23
# Egypt                      20
# Mali                       18
# Ecuador                    18
# Pakistan                   16
# Latvia                     14
# Bolivia                    14
# Name: root_domain, dtype: int64
# country_clean
# Cocos [Keeling] Islands              2
# Belize                               2
# Central African Republic             2
# Angola                               2
# Bahrain                              2
# Cameroon                             2
# Afghanistan                          2
# New Caledonia                        2
# Tuvalu                               2
# Namibia                              2
# North Macedonia                      2
# Lebanon                              2
# Ivory Coast                          2
# Republic Of Moldova                  2
# Nepal                                2
# Guinea                               2
# U.S. Virgin Islands                  2
# Greenland                            2
# French Polynesia                     2
# Papua New Guinea                     1
# Solomon Islands                      1
# San Marino                           1
# Palestine                            1
# Bermuda                              1
# Barbados                             1
# Sint Maarten                         1
# Turks And Caicos Islands             1
# Tajikistan                           1
# Tanzania                             1
# Tonga                                1
# Aruba                                1
# Armenia                              1
# Antigua And Barbuda                  1
# Anguilla                             1
# Ulan-Ude                             1
# Vanuatu                              1
# Bhutan                               1
# Eureka                               1
# Bonaire, Sint Eustatius, And Saba    1
# Niue                                 1
# French Guiana                        1
# Gabon                                1
# Guam                                 1
# Cyprus                               1
# Curaçao                              1
# Haiti                                1
# Iceland                              1
# Kosovo                               1
# Libya                                1
# Louisville                           1
# Madagascar                           1
# Malawi                               1
# Moscow                               1
# Cambodia                             1
# Burundi                              1
# Brunei                               1
# British Virgin Islands               1
# Faroe Islands                        1
# Niger                                1
# Laos                                 1
# Name: root_domain, dtype: int64

# %%
regions_raw = website_dataset.groupby('main_region')['root_domain'].count().sort_values(ascending = False)
print(regions_raw.head(60))
print(regions_raw.tail(60))

def clean_region(region):
  if not pd.isna(region):
    return region.strip(" '").title()

website_dataset['region_clean']=website_dataset['main_region'].apply(clean_region)
# Out:
# main_region
# ontario                   20032
# alberta                    7325
# quebec                     4816
# british columbia           2197
# england                    1711
# saskatchewan               1419
# manitoba                   1195
# texas                      1043
# california                  859
# victoria                    797
# new south wales             646
# new york                    606
# illinois                    438
# istanbul                    416
# western australia           363
# queensland                  357
# florida                     345
# pennsylvania                344
# nova scotia                 313
# ohio                        304
# virginia                    301
# michigan                    300
# indiana                     259
# dubai                       256
# gauteng                     239
# georgia                     230
# washington                  226
# north carolina              223
# massachusetts               219
# new jersey                  218
# south australia             216
# flanders                    215
# wisconsin                   212
# kansas                      183
# minnesota                   172
# new brunswick               171
# colorado                    168
# missouri                    166
# connecticut                 163
# kentucky                    162
# arizona                     158
# maryland                    148
# selangor                    141
# ile-de-france               137
# yamanashi                   135
# iowa                        133
# baden-wurttemberg           128
# kuala lumpur                125
# alabama                     124
# utah                        123
# tennessee                   122
# district of columbia        120
# abu dhabi                   119
# louisiana                   115
# western cape                113
# north rhine-westphalia      109
# oregon                      108
# nebraska                    107
# bavaria                     105
# south carolina              105
# Name: root_domain, dtype: int64
# main_region
# nantou                      1
# national capital            1
# nayarit                     1
# niamey                      1
# niigata                     1
# nisava                      1
# nizhegorodskaia oblast'     1
# noord-holland               1
# north central province      1
# north karelia               1
# north ossetia               1
# northeastern governorate    1
# northern region             1
# nur-sultan                  1
# oaxaca                      1
# obcina zalec                1
# obcina ziri                 1
# oberosterreich              1
# okayama                     1
# olomoucky kraj              1
# orel oblast                 1
# osh oblasty                 1
# otjozondjupa                1
# oueme                       1
# oyo state                   1
# pais vasco                  1
# murmansk                    1
# moskovskaia oblast'         1
# kumamoto                    1
# misiones                    1
# kurgan oblast               1
# kyiv                        1
# la libertad                 1
# la rioja                    1
# labuan                      1
# lampung                     1
# lara                        1
# leiria                      1
# liaoning                    1
# liberecky kraj              1
# lima                        1
# ljubljana                   1
# lobatse                     1
# lombardia                   1
# long an                     1
# machakos district           1
# madadeni                    1
# magadan oblast              1
# maldonado                   1
# maramures                   1
# zulia                       1
# mariy-el republic           1
# marrakesh-safi              1
# marsaskala                  1
# masantol                    1
# maule region                1
# meghalaya                   1
# melmoth                     1
# michoacan                   1
# abidjan                     1
# Name: root_domain, dtype: int64

# %%
cities_raw = website_dataset.groupby('main_city')['root_domain'].count().sort_values(ascending = False)
print(cities_raw.head(60))
print(cities_raw.tail(60))

def clean_city(main_city):
  if not pd.isna(main_city):
    if not (main_city.strip()).isalpha():
      return main_city.strip().translate({ord(ch): None for ch in '0123456789'}).title().strip()
    elif main_city == ' Company':
      return np.nan
    else:
      return main_city.strip(" '").title()

website_dataset['city_clean']=website_dataset['main_city'].apply(clean_city)
# Out:
# main_city
# toronto           3293
# calgary           2764
# edmonton          1909
# mississauga       1535
# ottawa             978
# montreal           929
# london             890
# winnipeg           854
# quebec             649
# brampton           629
# saskatoon          578
# markham            520
# hamilton           502
# vancouver          498
# oakville           491
# burlington         447
# kitchener          380
# richmond hill      373
# barrie             371
# regina             364
# istanbul           362
# scarborough        352
# north york         344
# windsor            318
# woodbridge         304
# dallas             279
# concord            270
# cambridge          257
# dubai              250
# guelph             250
# etobicoke          250
# red deer           237
# waterloo           234
# lethbridge         234
# kingston           222
# st. catharines     210
# vaughan            201
# grande prairie     197
# milton             193
# laval              180
# newmarket          177
# sherwood park      175
# oshawa             170
# brantford          169
# new york           168
# aurora             167
# bristol            162
# washington         159
# pickering          158
# whitby             153
# peterborough       151
# thornhill          151
# thunder bay        150
# medicine hat       141
# airdrie            138
# niagara falls      138
# sydney             137
# kelowna            137
# ajax               134
# melbourne          133
# Name: root_domain, dtype: int64
# main_city
# mont alto            1
# mont-laurier         1
# mont-saint-aignan    1
# montagnola           1
# morgan               1
# morganton            1
# moss vale            1
# moskva 473           1
# moskva 273           1
# moskva 284           1
# moskva 315           1
# moskva 316           1
# moskva 34            1
# moskva 357           1
# moskva 361           1
# moskva 362           1
# moskva 390           1
# moskva 4             1
# moskva 47            1
# moskva 474           1
# morningside          1
# moskva 54            1
# moskva 549           1
# moskva 590           1
# moskva 602           1
# moskva 78            1
# moskva 88            1
# moskva 90            1
# moskva-gsp 3         1
# moskva-gsp 6         1
# mosquero             1
# moss                 1
# moskva 22            1
# moskva 201           1
# moskva 20            1
# moskva 184           1
# morocco              1
# morpeth              1
# morrin               1
# morristown           1
# mortdale             1
# mortlake             1
# morton               1
# morton grove         1
# moruya               1
# morvant              1
# mos                  1
# mosbach              1
# moskva               1
# moskva 105           1
# moskva 12            1
# moskva 129           1
# moskva 137           1
# moskva 140           1
# moskva 143           1
# moskva 16            1
# moskva 170           1
# moskva 18            1
# moskva 180           1
#  Company             1
# Name: root_domain, dtype: int64

# %%
website_dataset.head(10)
# Out:
#             root_domain domain_suffix  ...          region_clean   city_clean
# 0      converterman.com           NaN  ...                  None         None
# 1   clothesencounter.ca            ca  ...  Prince Edward Island     Cardigan
# 2        investa.com.au        com.au  ...            Queensland     Brisbane
# 3     timminsgarage.com           com  ...               Ontario      Timmins
# 4          destinate.ca            ca  ...                  None         None
# 5           ironcrow.ca            ca  ...               Alberta      Calgary
# 6     springboarddm.com           com  ...               Ontario  Mississauga
# 7  stoneandtilesrus.com           com  ...               Ontario     Brampton
# 8          mdaccpap.com           com  ...               Ontario  Thunder Bay
# 9           micacchi.ca            ca  ...               Ontario      Toronto
#
# [10 rows x 17 columns]

# %%
website_dataset.columns
# Out:
# Index(['root_domain', 'domain_suffix', 'language', 'legal_name', 'main_city',
#        'main_country', 'main_region', 'phone', 'site_name', 'tld',
#        's_category', 'site_name_clean', 'category_clean', 'legal_name_clean',
#        'country_clean', 'region_clean', 'city_clean'],
#       dtype='object')

# %%
columns_to_keep = ['root_domain', 'domain_suffix', 'language', 'phone', 'site_name', 'tld',
                   'site_name_clean', 'category_clean', 'legal_name_clean',
       'country_clean', 'region_clean', 'city_clean']
website_dataset_clean = website_dataset[columns_to_keep].copy(deep = True)

del website_dataset, cities_raw, regions_raw, countries_raw, countries_cleaned, categories_raw, categories_cleaned
del site_names_raw, site_names_cleaned

# %%
website_dataset_clean.to_csv(pathFiles+'website_dataset_clean.csv',index=False)

# %% [markdown]
# After applying the cleaning on the website dataset, I will apply simillar cleaning to the Google and Facebook datasets. The purpose of this step is to create as much consistency as possible accross the 3 datasets before applying any sort of matching algorithm.

# %%
google_dataset.describe(include='all')
# Out:
#                          address  ...        domain
# count                     330552  ...        356520
# unique                    282513  ...         72010
# top     Montreal, Quebec, Canada  ...  facebook.com
# freq                        1111  ...         71983
# mean                         NaN  ...           NaN
# std                          NaN  ...           NaN
# min                          NaN  ...           NaN
# 25%                          NaN  ...           NaN
# 50%                          NaN  ...           NaN
# 75%                          NaN  ...           NaN
# max                          NaN  ...           NaN
#
# [11 rows x 15 columns]

# %%
domain_count = google_dataset.groupby('domain').size().sort_values(ascending = False)
print(domain_count.head(60))
print(domain_count.tail(60))
# Out:
# domain
# facebook.com                  71983
# postoffice.co.uk               6010
# instagram.com                  5647
# ihg.com                        4356
# marriott.com                   3979
# hilton.com                     3477
# doctolib.fr                    3105
# ameripriseadvisors.com         2378
# choicehotels.com               1625
# uhaul.com                      1518
# gov.uk                         1511
# bit.ly                         1486
# spar.co.uk                     1428
# 411habitation.com              1097
# bestwestern.com                1093
# etsy.com                       1054
# dignitymemorial.com            1050
# uchealth.org                   1032
# anchorhanover.org.uk           1012
# vagaro.com                      992
# iuhealth.org                    991
# ochsner.org                     978
# sanfordhealth.org               959
# motel6.com                      929
# kindercare.com                  877
# homehardware.ca                 857
# uwmedicine.org                  851
# wexnermedical.osu.edu           829
# amazon.co.uk                    826
# atriumhealth.org                808
# acehardware.com                 800
# napaonline.com                  769
# linktr.ee                       764
# lifespan.org                    730
# goarmy.com                      727
# pennmedicine.org                724
# childrenshospital.org           723
# iadfrance.fr                    718
# hopkinsmedicine.org             717
# premier-stores.co.uk            708
# guardian-ida-pharmacies.ca      697
# uwhealth.org                    679
# ohsu.edu                        674
# statefarm.com                   672
# linkedin.com                    668
# airbnb.com                      666
# youtube.com                     634
# va.gov                          608
# bannerhealth.com                606
# kumon.com                       595
# ouhealth.com                    571
# anugo.ca                        557
# massagebook.com                 547
# albertahealthservices.ca        541
# pharmasave.com                  540
# 411sante.com                    529
# achurchnearyou.com              527
# brookdale.com                   514
# mass.gov                        510
# stanfordhealthcare.org          508
# dtype: int64
# domain
# nochallengetmg.com           1
# noblewoodworks.com           1
# noblewellservices.com        1
# noblewealthfinancial.com     1
# noblevanity.ca               1
# nobletonlakesgolf.com        1
# nobletonfeedmill.com         1
# nobleroofingniagara.com      1
# noblereign.com               1
# nobleparksc.vic.edu.au       1
# noblepainting.co.uk          1
# noblemortgages.ca            1
# noblemindbody.ca             1
# noblelocksmith.ca            1
# noblehall.ca                 1
# nobleestates.com             1
# nobledelivery.ca             1
# noblecreations.ca            1
# noblecountysheriff.org       1
# noblechoicecoaching.com      1
# noblebistro.com              1
# nobilitycleaning.ca          1
# nobesgranite.com             1
# nobel.com.tr                 1
# nobbscpa.com                 1
# noariframing.com             1
# noaisys.com                  1
# noahsplay.com                1
# nobullrv.ca                  1
# nocowanie.pl                 1
# nomdecodewp.com              1
# nodaccess.com                1
# nomadtelecom.ca              1
# nomadstages.com              1
# nomadmechanical.ca           1
# nomadlogic.com               1
# nomadicdisplay.ca            1
# nomadhomes.com               1
# nomadetransport.com          1
# nomadeexpertsconseils.com    1
# nomadechef.com               1
# nomade-ergo.com              1
# nomadacharters.com           1
# nomad-ad.ca                  1
# nom.nl                       1
# nolovelosttattoos.com        1
# nollclimatecare.com          1
# nolimittreeservicellc.com    1
# nolimitrestoration.com       1
# nolabaking.com               1
# nokomiscraftales.com         1
# nokiantyres.ru               1
# nokarafarms.ca               1
# noirsalonspa.com             1
# noiretbois.com               1
# nohands.ca                   1
# nofixedaddressinc.com        1
# node1computers.com           1
# noddem.com                   1
# 007group.com                 1
# dtype: int64

# %%
google_dataset.query('domain == "youtube.com"').head(5)
# Out:
#                                                address  ...       domain
# 900                                                NaN  ...  youtube.com
# 901                                                NaN  ...  youtube.com
# 902                                                NaN  ...  youtube.com
# 903                                                NaN  ...  youtube.com
# 904  COMPANY IMK PRODUCTION، Rue du Midi 51، 1000 B...  ...  youtube.com
#
# [5 rows x 15 columns]

# %% [markdown]
# Based on the output above it seems that the domain is not a very reliable way of uniquely identifying a company. There are a lot of them which have facebook.com, instagram.com, youtube.com as their domain. They're probably Facebook pages or Instagram / Youtube channels, but for the purpose of building a better dataset, it's not useful for linking data.

# %%
countries_raw = google_dataset.groupby('country_name').size().sort_values(ascending = False)
print(countries_raw.head(30))
print(countries_raw.tail(30))
google_dataset['country_name_consistent'] = google_dataset['country_name'].apply(lambda x: x.strip().title() if not pd.isna(x) else x)
del countries_raw
# Out:
# country_name
# united states           132132
# canada                   86447
# united kingdom           42311
# australia                12612
# france                    8960
# germany                   2401
# new zealand               2239
# malaysia                  2036
# belgium                   2006
# south africa              1733
# india                     1555
# turkey                    1474
# united arab emirates      1437
# netherlands               1263
# russia                    1183
# japan                      954
# mexico                     817
# spain                      564
# philippines                535
# italy                      463
# hong kong                  394
# poland                     388
# taiwan                     351
# qatar                      325
# ireland                    260
# vietnam                    250
# greece                     247
# switzerland                234
# china                      234
# denmark                    219
# dtype: int64
# country_name
# tonga                               3
# martinique                          3
# samoa                               3
# seychelles                          3
# new caledonia                       2
# north macedonia                     2
# bermuda                             2
# maldives                            2
# sierra leone                        2
# kenya                               2
# sint maarten                        2
# american samoa                      2
# central african republic            2
# french guiana                       2
# saint vincent and the grenadines    2
# saint lucia                         1
# south sudan                         1
# st kitts and nevis                  1
# dominica                            1
# reunion                             1
# faroe islands                       1
# lesotho                             1
# jersey                              1
# isle of man                         1
# iran                                1
# hashemite kingdom of jordan         1
# guinea-bissau                       1
# french polynesia                    1
# comoros                             1
# Åland                               1
# dtype: int64

# %%
country_codes_raw = google_dataset.groupby('country_code').size().sort_values(ascending = False)
print(country_codes_raw.head(20))
print(country_codes_raw.tail(20))

def clean_codes(country_code):
  if not pd.isna(country_code):
    if country_code == '001':
      return np.nan
    else:
      return country_code.strip().upper()
  
  return country_code

google_dataset['country_code_consistent'] = google_dataset['country_code'].apply(clean_codes)
google_dataset['phone_country_code_consistent'] = google_dataset['phone_country_code'].apply(clean_codes)
# Out:
# country_code
# us    110083
# ca     95379
# gb     44919
# au     12637
# fr      9432
# nz      2429
# de      2314
# be      2030
# my      1757
# za      1681
# tr      1643
# in      1480
# ae      1394
# nl      1229
# jp      1078
# ru       994
# mx       959
# sg       797
# hk       664
# ph       549
# dtype: int64
# country_code
# cf    2
# mq    2
# ky    2
# mh    2
# gf    2
# fo    1
# km    1
# gw    1
# kp    1
# gi    1
# gd    1
# ls    1
# vg    1
# sl    1
# dm    1
# nr    1
# pf    1
# tm    1
# ci    1
# im    1
# dtype: int64

# %% [markdown]
# There are 3 fields which point to the same information - country_code, country_name, phone_country_code. These all represent a form of Country information. I will unify them in a single field.

# %%
print('''There are {} instances where the country code does not exist, 
but the phone country code exists'''
.format(google_dataset[google_dataset['country_code_consistent'].isnull() & google_dataset['phone_country_code_consistent'].notna()].shape[0]))
# Out:
# There are 0 instances where the country code does not exist,
# but the phone country code exists

# %% [markdown]
# This means that the phone country code is redundant at this step. I can turn it into a dialing code at a later point using country information.

# %%
countries_iso = pd.read_csv(pathFiles + 'iso_codes.csv')
countries_iso.head()
# Out:
#              Name Code
# 0     Afghanistan   AF
# 1   Åland Islands   AX
# 2         Albania   AL
# 3         Algeria   DZ
# 4  American Samoa   AS

# %%
print(countries_iso.query('Name == "Namibia"'))
print(countries_iso[countries_iso['Code'].isna()])
countries_iso['Code'] = countries_iso['Code'].fillna('NA')
print(countries_iso.query('Name == "Namibia"'))
# Out:
#         Name Code
# 153  Namibia  NaN
#         Name Code
# 153  Namibia  NaN
#         Name Code
# 153  Namibia   NA

# %%
google_dataset = google_dataset.merge(countries_iso, how = 'left', left_on = 'country_code_consistent', right_on = 'Code')

# %%
google_dataset.query('country_code_consistent == "NA"').head(5)
# Out:
#                                         address  ... Code
# 11045     Nelson Mandela Ave, Windhoek, Namibia  ...   NA
# 53124                                       NaN  ...   NA
# 83134  116 Robert Mugabe Ave, Windhoek, Namibia  ...   NA
# 83724           B1 Main Road, Ondangwa, Namibia  ...   NA
# 88008      Hendrik Witbooi, Swakopmund, Namibia  ...   NA
#
# [5 rows x 20 columns]

# %%
google_dataset[google_dataset['Code'].isna()].head(5)
# Out:
#                                               address  ... Code
# 4                                                 NaN  ...  NaN
# 13               1800 Orleans St, Baltimore, MD 21287  ...  NaN
# 17        363 Horton St E, London, ON N6B 1L6, Canada  ...  NaN
# 21  Europa House, Newton Ln, Wigston LE18 3SE, Uni...  ...  NaN
# 28                                                NaN  ...  NaN
#
# [5 rows x 20 columns]

# %%
country_analysis = google_dataset.groupby(['country_name_consistent','Name']).size()
print(country_analysis.head(40))
# Out:
# country_name_consistent  Name
# Afghanistan              Afghanistan                      4
# Albania                  Albania                         32
# Algeria                  Algeria                         20
#                          Ukraine                          1
# American Samoa           American Samoa                   2
# Andorra                  Andorra                         12
# Angola                   Angola                           8
# Argentina                Argentina                      113
#                          Belgium                          1
#                          Nigeria                          1
#                          South Africa                     1
# Armenia                  Armenia                         16
# Aruba                    Aruba                            8
# Australia                Australia                    11830
#                          France                           1
#                          Kenya                            1
#                          Nepal                            1
#                          New Zealand                      1
#                          Singapore                        1
#                          Spain                            1
#                          United Kingdom                  24
#                          United States                    2
# Austria                  Austria                        148
#                          Germany                          1
# Azerbaijan               Azerbaijan                      10
#                          Iran, Islamic Republic of        1
# Bahamas                  Bahamas                         12
# Bahrain                  Bahrain                         18
#                          Jordan                           1
# Bangladesh               Bangladesh                     127
# Barbados                 Barbados                         8
# Belarus                  Belarus                         21
# Belgium                  Belgium                       1911
#                          Canada                           1
#                          France                           3
#                          Hong Kong                        1
#                          Singapore                        1
#                          United States                    1
# Belize                   Belize                           6
# Benin                    Benin                            9
# dtype: int64

# %%
print('''There are {0:,} instances where the country name is not originally present,
but based on the code the country can be determined'''
.format(google_dataset[google_dataset['country_name_consistent'].isna() & google_dataset['Name'].notna()].shape[0]))
# Out:
# There are 26,651 instances where the country name is not originally present,
# but based on the code the country can be determined

# %%
def fill_country(row):
  if not pd.isna(row['country_name_consistent']):
    return row['country_name_consistent']
  else:
    return row['Name']
google_dataset['country_final']=google_dataset[['country_name_consistent','Name']].apply(lambda row: fill_country(row),axis=1)

google_dataset[['country_name_consistent','country_final']].describe()
# Out:
#        country_name_consistent  country_final
# count                   311039         337690
# unique                     187            234
# top              United States  United States
# freq                    132132         136976

# %%
cities_raw = google_dataset.groupby('city').size().sort_values(ascending = False)
print(cities_raw.head(60))
print(cities_raw.tail(60))
# Out:
# city
# calgary             4591
# toronto             3769
# edmonton            3428
# london              3374
# montreal            2780
# mississauga         2729
# new york            1782
# quebec              1766
# ottawa              1705
# winnipeg            1625
# north york          1607
# indianapolis        1562
# dallas              1536
# brampton            1407
# richmond            1394
# bristol             1350
# columbus            1330
# charlotte           1330
# seattle             1326
# houston             1323
# vancouver           1294
# portland            1240
# oklahoma city       1239
# hamilton            1217
# philadelphia        1214
# boston              1164
# madison             1115
# scarborough         1112
# saskatoon           1103
# phoenix             1051
# cambridge           1010
# burlington          1007
# markham              949
# atlanta              944
# chicago              925
# birmingham           915
# aurora               914
# baltimore            912
# laval                889
# windsor              887
# oakville             879
# manchester           877
# concord              876
# woodbridge           858
# dubai                822
# tucson               815
# etobicoke            800
# los angeles          799
# regina               783
# jacksonville         771
# richmond hill        761
# lexington            759
# louisville           741
# glasgow              740
# kitchener            738
# colorado springs     719
# san antonio          702
# baton rouge          688
# san diego            687
# barrie               677
# dtype: int64
# city
# leksand                      1
# leitches creek               1
# leinster                     1
# leimen                       1
# warangal                     1
# leigh sinton                 1
# leidschendam                 1
# leiderdorp                   1
# lehragaga                    1
# lehigh acres                 1
# lead hill                    1
# le vesinet                   1
# le transloy                  1
# le teilleul                  1
# le fauga                     1
# le deschaux                  1
# le coudray-montceaux         1
# le chatelet-sur-retourne     1
# le center                    1
# le castera                   1
# le cannet                    1
# le cailar                    1
# le brignon                   1
# le bourget                   1
# le bouchet-saint-nicolas     1
# laxton                       1
# lawtey                       1
# warlaing                     1
# warluis                      1
# lawngtlai                    1
# lawndale                     1
# lawn hill                    1
# lawley                       1
# lavonia                      1
# lavinia                      1
# le fayel                     1
# le fossat                    1
# le grand-quevilly            1
# le perthus                   1
# le tech                      1
# le sueur                     1
# le roy                       1
# le rove                      1
# le pre-saint-gervais         1
# le plessier-rozainvillers    1
# le pian-medoc                1
# le petit-quevilly            1
# le pertuis                   1
# le pecq                      1
# le grand-saconnex            1
# le palais                    1
# le nouvion-en-thierache      1
# le mont-sur-lausanne         1
# le mesnil-esnard             1
# le mesnil-en-thelle          1
# le mee-sur-seine             1
# le lamentin                  1
# le kremlin-bicetre           1
# le houga                     1
# zywiec                       1
# dtype: int64

# %%
cities_raw[cities_raw.index.str.startswith('moskva')].head(20)
# Out:
# city
# moskva 90     1
# moskva 404    1
# moskva 342    1
# dtype: int64

# %%
cities_raw[cities_raw.index.str.startswith('dublin')].head(20)
# Out:
# city
# dublin       196
# dublin 22      3
# dublin 2       2
# dublin 1       2
# dublin 7       1
# dublin 4       1
# dublin 24      1
# dublin 15      1
# dtype: int64

# %%
regions_raw = google_dataset.groupby('region_name').size().sort_values(ascending = False)
print(regions_raw.head(60))
print(regions_raw.tail(60))
# Out:
# region_name
# ontario                 40045
# england                 37009
# quebec                  16999
# alberta                 13591
# texas                   11306
# california              10293
# british columbia         6552
# florida                  5206
# new york                 4846
# north carolina           4454
# ohio                     4366
# indiana                  4179
# virginia                 3817
# arizona                  3809
# washington               3775
# pennsylvania             3759
# new south wales          3672
# michigan                 3661
# massachusetts            3585
# wisconsin                3513
# illinois                 3439
# colorado                 3418
# saskatchewan             3098
# georgia                  3072
# louisiana                3070
# victoria                 3069
# oklahoma                 2826
# kentucky                 2716
# scotland                 2694
# tennessee                2693
# queensland               2435
# manitoba                 2390
# oregon                   2351
# maryland                 2273
# new jersey               2159
# missouri                 2117
# occitanie                2084
# alabama                  1829
# ile-de-france            1829
# kansas                   1809
# iowa                     1762
# south carolina           1693
# arkansas                 1654
# wales                    1646
# western australia        1626
# mississippi              1525
# nova scotia              1517
# nebraska                 1510
# connecticut              1483
# minnesota                1438
# hauts-de-france          1422
# nevada                   1384
# rhode island             1346
# north dakota             1332
# maine                    1256
# new hampshire            1231
# auvergne-rhone-alpes     1191
# new brunswick            1179
# idaho                    1165
# south australia          1118
# dtype: int64
# region_name
# departamento de carazo                1
# departamento de chimaltenango         1
# krasnoiarskii krai                    1
# departamento del quiche               1
# l-imdina                              1
# tinh kien giang                       1
# reunion                               1
# dhi qar                               1
# tinh lang son                         1
# tinh lao cai                          1
# dire dawa                             1
# kwamashu                              1
# kujalleq                              1
# tinh phu yen                          1
# diyarbakir                            1
# tinh quang ninh                       1
# departamento del huila                1
# donga                                 1
# krasnodarskii krai                    1
# dublin 15                             1
# dublin 2                              1
# kotayk                                1
# dublin 24                             1
# dublin 4                              1
# dublin 7                              1
# kostroma oblast                       1
# koprivnicko-krizevacka zupanija       1
# koper/capodistria - dostava           1
# kon tum                               1
# la pampa                              1
# departamento del caqueta              1
# departamento de chiquimula            1
# departamento de olancho               1
# departamento de chuquisaca            1
# tinh binh thuan                       1
# departamento de escuintla             1
# tinh cao bang                         1
# departamento de huehuetenango         1
# departamento de izabal                1
# departamento de jutiapa               1
# lenasia                               1
# departamento de leon                  1
# legazpi city                          1
# lara                                  1
# departamento de norte de santander    1
# departamento de presidente hayes      1
# departamento del alto parana          1
# departamento de rivas                 1
# departamento de sacatepequez          1
# departamento de salto                 1
# departamento de san jose              1
# departamento de san miguel            1
# lampung                               1
# departamento de santa ana             1
# lady frere                            1
# labe region                           1
# laane                                 1
# departamento de totonicapan           1
# departamento de zacapa                1
# provincia de cotopaxi                 1
# dtype: int64

# %%
regions_raw[regions_raw.index.str.startswith('dublin')]
# Out:
# region_name
# dublin 22    3
# dublin 1     2
# dublin 15    1
# dublin 2     1
# dublin 24    1
# dublin 4     1
# dublin 7     1
# dtype: int64

# %%
regions_raw[regions_raw.index.str.startswith('moskva')]
# Out:
# region_name
# moskva    3
# dtype: int64

# %%
def clean_region_or_city(region_or_city):
  if not pd.isna(region_or_city):
    if not (region_or_city.strip()).isalpha():
      return region_or_city.strip().translate({ord(ch): None for ch in '0123456789'}).title().strip()
    else:
      return region_or_city.strip(" '").title()

google_dataset['city_consistent'] = google_dataset['city'].apply(clean_region_or_city)
google_dataset['region_consistent'] = google_dataset['region_name'].apply(clean_region_or_city)

# %%
google_dataset[google_dataset['city'].str.startswith('moskva') & google_dataset['city'].notna()].head()
# Out:
#                                                   address  ... region_consitent
# 225888  140125, Московская обл, 1-я Стекольная ул., 1,...  ...           Moskva
# 270379    Миклухо-Маклая ул 42 Москва, АО, Russia, 117342  ...           Moskva
# 320679  129090, Москва, Троицкая ул., д, Troitskaya Ul...  ...           Moskva
#
# [3 rows x 23 columns]

# %%
google_dataset.columns
# Out:
# Index(['address', 'category', 'city', 'country_code', 'country_name', 'name',
#        'phone', 'phone_country_code', 'raw_address', 'raw_phone',
#        'region_code', 'region_name', 'text', 'zip_code', 'domain',
#        'country_name_consistent', 'country_code_consistent',
#        'phone_country_code_consistent', 'Name', 'Code', 'country_final',
#        'city_consitent', 'region_consitent'],
#       dtype='object')

# %%
columns_to_keep = ['address', 'category', 'name',
       'phone', 'raw_address', 'raw_phone',
       'region_code', 'region_name', 'text', 'zip_code', 'domain',
        'country_final',
       'city_consistent', 'region_consistent']
google_dataset_clean = google_dataset[columns_to_keep]
google_dataset_clean.head()
# Out:
#                                              address  ... region_consistent
# 0  28 Central Coast Hwy, West Gosford NSW 2250, A...  ...   New South Wales
# 1   400 Scott St, St. Catharines, ON L2M 3W2, Canada  ...           Ontario
# 2      191 Pleasant St, Yarmouth, NS B5A 2J9, Canada  ...       Nova Scotia
# 3  11040 Santa Monica Blvd Suite 370, Los Angeles...  ...        California
# 4                                                NaN  ...              None
#
# [5 rows x 14 columns]

# %%
google_dataset_clean.to_csv(pathFiles + 'google_dataset_clean.csv' , quotechar='"', escapechar='\\')

# %%
facebook_dataset = pd.read_csv(pathFiles+'facebook dataset.csv', quotechar='"', escapechar='\\')

# %%
facebook_dataset.describe(include='all')
# Out:
#                          domain  ...  zip_code
# count                     72010  ...     36049
# unique                    72010  ...     26223
# top     safetytrainingltd.co.uk  ...  victoria
# freq                          1  ...       463
# mean                        NaN  ...       NaN
# std                         NaN  ...       NaN
# min                         NaN  ...       NaN
# 25%                         NaN  ...       NaN
# 50%                         NaN  ...       NaN
# 75%                         NaN  ...       NaN
# max                         NaN  ...       NaN
#
# [11 rows x 16 columns]

# %%
# To do - make country, region, city consitent using a similar approach to google dataset
# Again country code seems to have more coverage than country. To be combined with phone country code and then with iso codes
# domain seems to be unique
# phone is different than from google
# The best approach would be to combine the 3 datasets using common elements - Country, City/Region
# Then combine and keep only 1 using string matchin

# %%
countries_raw = facebook_dataset.groupby('country_name').size().sort_values(ascending = False)
print(countries_raw.head(60))
print(countries_raw.tail(60))
# Out:
# country_name
# canada                  31160
# united states            6367
# australia                1614
# united kingdom            939
# russia                    508
# united arab emirates      424
# south africa              419
# germany                   391
# turkey                    385
# netherlands               376
# belgium                   317
# malaysia                  294
# france                    282
# singapore                 222
# india                     164
# hong kong                 157
# greece                    146
# taiwan                    145
# poland                    124
# spain                     103
# south korea                71
# philippines                59
# china                      55
# new zealand                55
# italy                      47
# vietnam                    47
# japan                      42
# austria                    31
# sweden                     28
# bangladesh                 24
# indonesia                  23
# switzerland                20
# norway                     19
# denmark                    19
# qatar                      17
# sri lanka                  16
# mexico                     15
# romania                    12
# colombia                   11
# ecuador                    11
# saudi arabia               11
# finland                    11
# pakistan                   10
# chile                      10
# brazil                     10
# ireland                     8
# hungary                     8
# panama                      8
# oman                        7
# argentina                   7
# egypt                       7
# ukraine                     7
# thailand                    7
# estonia                     6
# czechia                     6
# croatia                     5
# liechtenstein               5
# honduras                    5
# kuwait                      5
# albania                     5
# dtype: int64
# country_name
# honduras                       5
# kuwait                         5
# albania                        5
# portugal                       5
# el salvador                    5
# dominican republic             5
# costa rica                     5
# trinidad and tobago            4
# republic of lithuania          3
# serbia                         3
# peru                           3
# israel                         3
# venezuela                      3
# georgia                        2
# gibraltar                      2
# belarus                        2
# bulgaria                       2
# zimbabwe                       2
# iceland                        2
# zambia                         2
# togo                           2
# slovakia                       2
# mozambique                     2
# paraguay                       2
# kyrgyzstan                     1
# latvia                         1
# senegal                        1
# brunei                         1
# guam                           1
# botswana                       1
# bosnia and herzegovina         1
# bolivia                        1
# slovenia                       1
# tajikistan                     1
# barbados                       1
# guatemala                      1
# u.s. virgin islands            1
# uganda                         1
# armenia                        1
# uzbekistan                     1
# angola                         1
# cambodia                       1
# réunion                        1
# republic of moldova            1
# morocco                        1
# gabon                          1
# french polynesia               1
# lebanon                        1
# kosovo                         1
# mauritius                      1
# monaco                         1
# iraq                           1
# puerto rico                    1
# myanmar                        1
# namibia                        1
# new caledonia                  1
# nicaragua                      1
# nigeria                        1
# hashemite kingdom of jordan    1
# luxembourg                     1
# dtype: int64

# %%
country_codes_raw = facebook_dataset.groupby('country_code').size().sort_values(ascending = False)
print(country_codes_raw.head(60))
print(country_codes_raw.tail(60))
# Out:
# country_code
# ca    41955
# us     6703
# au     1670
# gb     1240
# ru      538
# tr      508
# ae      456
# za      445
# de      441
# nl      393
# jp      336
# be      331
# my      313
# fr      294
# sg      227
# in      212
# gr      173
# hk      163
# tw      162
# pl      140
# kr      125
# es      115
# nz       72
# ph       64
# cn       57
# vn       55
# it       52
# bd       35
# at       32
# qa       30
# se       29
# id       28
# lk       22
# mx       21
# ch       20
# no       19
# dk       19
# th       16
# br       16
# ec       15
# co       15
# ro       14
# pa       13
# sa       12
# fi       12
# om       12
# ar       12
# pk       11
# cl       10
# ie        9
# eg        9
# hu        8
# gt        7
# ua        7
# cz        7
# il        7
# sv        7
# pr        7
# kw        6
# ee        6
# dtype: int64
# country_code
# ve    4
# bs    3
# lt    3
# rs    3
# bg    2
# by    2
# ba    2
# bb    2
# gi    2
# ge    2
# bz    2
# zw    2
# iq    2
# lu    2
# is    2
# sk    2
# mz    2
# mt    2
# md    2
# py    2
# ug    2
# tg    2
# vg    2
# zm    2
# vi    2
# uy    1
# sn    1
# si    1
# xk    1
# bw    1
# am    1
# ao    1
# bo    1
# bn    1
# bh    1
# sx    1
# uz    1
# tj    1
# re    1
# ni    1
# pf    1
# np    1
# jm    1
# gy    1
# gu    1
# ke    1
# kg    1
# kh    1
# ga    1
# lv    1
# fo    1
# ma    1
# mc    1
# mk    1
# mm    1
# mo    1
# mu    1
# nc    1
# ng    1
# lb    1
# dtype: int64

# %%
facebook_dataset[facebook_dataset['country_name'].isna() & facebook_dataset['country_code'].notna()].shape[0]
# Out:
# 12471

# %%
facebook_dataset[facebook_dataset['country_code'].isna() & facebook_dataset['phone_country_code'].notna()].shape[0]
# Out:
# 0

# %%
region_names_raw = facebook_dataset.groupby('region_name').size().sort_values(ascending = False)
print(region_names_raw.head(60))
print(region_names_raw.tail(60))
# Out:
# region_name
# ontario              16710
# alberta               6487
# quebec                3764
# british columbia      1541
# saskatchewan          1217
# manitoba              1036
# england                896
# texas                  888
# victoria               482
# california             471
# new south wales        470
# new york               343
# illinois               300
# pennsylvania           294
# dubai                  283
# virginia               262
# western australia      259
# moscow                 256
# gauteng                250
# indiana                229
# michigan               220
# queensland             218
# ohio                   213
# istanbul               198
# nova scotia            196
# florida                188
# flanders               178
# wisconsin              161
# massachusetts          160
# washington             153
# north carolina         148
# new jersey             141
# connecticut            139
# south australia        139
# georgia                138
# new brunswick          115
# minnesota              113
# kuala lumpur           111
# baden-wurttemberg      110
# abu dhabi              105
# missouri               105
# iowa                   104
# selangor               100
# maryland                94
# kansas                  94
# colorado                90
# attica                  89
# arizona                 89
# tennessee               88
# rheinland-pfalz         88
# south holland           83
# alabama                 79
# kentucky                78
# arkansas                76
# north holland           72
# louisiana               68
# south carolina          68
# taipei city             67
# north brabant           65
# mississippi             65
# dtype: int64
# region_name
# grand port district                1
# gorod bishkek                      1
# transbaikal territory              1
# eastern province                   1
# ekiti state                        1
# trondelag                          1
# esch-sur-alzette                   1
# estuaire                           1
# flevoland                          1
# transnistria                       1
# gaborone                           1
# goa                                1
# tottori                            1
# gangwon-do                         1
# toshkent shahri                    1
# toplica                            1
# tiumenskaia oblast'                1
# germiston                          1
# gisborne                           1
# iles du vent                       1
# talisay city                       1
# styria                             1
# sogn og fjordane                   1
# soshanguve                         1
# khanty-mansia                      1
# khomas                             1
# songkhla                           1
# komi                               1
# somogy megye                       1
# koprivnicko-krizevacka zupanija    1
# sivas                              1
# karelia                            1
# kymenlaakso                        1
# kyoto                              1
# latium                             1
# lazio                              1
# leningradskaia oblast'             1
# leningradskaya oblast'             1
# liberecky kraj                     1
# south province                     1
# karaman                            1
# islamabad                          1
# jonkoping                          1
# ivanovskaya oblast'                1
# st.-petersburg                     1
# jalisco                            1
# jammu and kashmir                  1
# jeju-do                            1
# jeollanam-do                       1
# johannesburg                       1
# jurong east street 24              1
# karabuek                           1
# kahramanmaras                      1
# southern savonia                   1
# kamphaeng phet                     1
# kanagawa                           1
# southern province                  1
# kanton graubunden                  1
# kanton zurich                      1
# abruzzo                            1
# dtype: int64

# %%
cities_raw = facebook_dataset.groupby('city').size().sort_values(ascending = False)
print(cities_raw.head(60))
print(cities_raw.tail(60))
# Out:
# city
# toronto            2713
# calgary            2529
# edmonton           1792
# mississauga        1580
# ottawa              816
# winnipeg            799
# brampton            653
# london              642
# markham             553
# saskatoon           529
# montreal            508
# oakville            497
# hamilton            482
# burlington          441
# richmond hill       403
# quebec              401
# kitchener           383
# vancouver           369
# dallas              361
# regina              356
# barrie              351
# windsor             338
# woodbridge          325
# dubai               283
# guelph              260
# moscow              260
# cambridge           246
# lethbridge          239
# red deer            230
# waterloo            226
# grande prairie      204
# kingston            202
# newmarket           191
# vaughan             188
# oshawa              179
# sherwood park       173
# milton              171
# whitby              169
# brantford           161
# greater sudbury     156
# aurora              155
# peterborough        153
# thunder bay         152
# pickering           142
# ajax                142
# thornhill           130
# medicine hat        124
# airdrie             122
# sherbrooke          121
# laval               119
# colleyville         117
# niagara falls       117
# sydney              113
# kuala lumpur        111
# langley             110
# istanbul            110
# abu dhabi           105
# belleville          105
# kelowna             100
# longueuil            99
# dtype: int64
# city
# mosquero               1
# mossel bay             1
# motherwell             1
# morphett vale          1
# morlaas                1
# muscatine              1
# morin-heights          1
# moonee ponds           1
# moore park             1
# moorebank              1
# moraga                 1
# moraleja de enmedio    1
# moravia                1
# morbi mdg              1
# morecambe              1
# moree                  1
# morehead city          1
# moreno valley          1
# moreuil                1
# morgan city            1
# morganfield            1
# morganton              1
# mount albert           1
# mount calm             1
# mount clear            1
# mount evelyn           1
# mulgoa                 1
# mulheim an der ruhr    1
# mullheim               1
# mullumbimby            1
# multan                 1
# mundaring              1
# munising               1
# munno para             1
# munno para downs       1
# munster                1
# muratli                1
# murdoch                1
# murgon                 1
# murphy                 1
# murray bridge          1
# muju                   1
# muhlhausen             1
# mudgeeraba             1
# mount rainier          1
# mount forest           1
# mount gilead           1
# mount helena           1
# mount joy              1
# mount louisa           1
# mount orab             1
# mount royal            1
# mudgee                 1
# mount shasta           1
# mountain home          1
# mountain iron          1
# mountain lakes         1
# mountain pine          1
# mozhaysk               1
# 100.yil                1
# dtype: int64

# %%
facebook_dataset['country_name_consistent'] = facebook_dataset['country_name'].apply(lambda x: x.strip().title() if not pd.isna(x) else x)

# %%
def clean_codes(country_code):
  if not pd.isna(country_code):
    if country_code == '001':
      return np.nan
    else:
      return country_code.strip().upper()
  
  return country_code

facebook_dataset['country_code_consistent'] = facebook_dataset['country_code'].apply(clean_codes)

# %%
countries_iso = pd.read_csv(pathFiles + 'iso_codes.csv', header = 0, names = ['ISO_Country_Name', 'ISO_2_Country_Code'])
countries_iso['ISO_2_Country_Code'] = countries_iso['ISO_2_Country_Code'].fillna('NA')
facebook_dataset = facebook_dataset.merge(countries_iso, how = 'left', left_on = 'country_code_consistent', right_on = 'ISO_2_Country_Code')

def fill_country(row):
  if not pd.isna(row['country_name_consistent']):
    return row['country_name_consistent']
  else:
    return row['ISO_Country_Name']

facebook_dataset['country_final']=facebook_dataset[['country_name_consistent','ISO_Country_Name']].apply(lambda row: fill_country(row),axis=1)

facebook_dataset[['country_name_consistent','country_final']].describe()
# Out:
#        country_name_consistent country_final
# count                    45404         57875
# unique                     117           142
# top                     Canada        Canada
# freq                     31160         41955

# %%
"leningradskaia oblast'".isalpha()
# Out:
# False

# %%
def clean_region_or_city(region_or_city):
  if not pd.isna(region_or_city):
    if not (region_or_city.strip()).isalpha():
      return region_or_city.strip().translate({ord(ch): None for ch in '0123456789'}).title().strip()
    elif region_or_city in ["leningradskaia oblast'","leningradskaya oblast'"]:
      return "Leningradskaya Oblast"
    elif region_or_city == "st.-petersburg":
      return "St Petersburg"
    else:
      return region_or_city.strip(" '").title()

facebook_dataset['city_consistent'] = facebook_dataset['city'].apply(clean_region_or_city)
facebook_dataset['region_consistent'] = facebook_dataset['region_name'].apply(clean_region_or_city)

# %%
facebook_dataset.head()
# Out:
#                     domain  ... region_consistent
# 0       euro-hygiene-34.fr  ...         Occitanie
# 1  lakesidehomeservices.ca  ...              None
# 2        rossiterboats.com  ...              None
# 3     caa-architecture.com  ...  British Columbia
# 4            apexsurety.ca  ...          Manitoba
#
# [5 rows x 23 columns]

# %%
facebook_dataset.columns
# Out:
# Index(['domain', 'address', 'categories', 'city', 'country_code',
#        'country_name', 'description', 'email', 'link', 'name', 'page_type',
#        'phone', 'phone_country_code', 'region_code', 'region_name', 'zip_code',
#        'country_name_consistent', 'country_code_consistent',
#        'ISO_Country_Name', 'ISO_2_Country_Code', 'country_final',
#        'city_consistent', 'region_consistent'],
#       dtype='object')

# %%
columns_to_keep = ['domain', 'address', 'categories', 
 'description', 'email', 'link', 'name', 'page_type',
       'phone',  'region_code',  'zip_code', 'country_final',
       'city_consistent', 'region_consistent']
facebook_dataset_clean = facebook_dataset[columns_to_keep]
facebook_dataset_clean.head()
# Out:
#                     domain  ... region_consistent
# 0       euro-hygiene-34.fr  ...         Occitanie
# 1  lakesidehomeservices.ca  ...              None
# 2        rossiterboats.com  ...              None
# 3     caa-architecture.com  ...  British Columbia
# 4            apexsurety.ca  ...          Manitoba
#
# [5 rows x 14 columns]

# %%
facebook_dataset_clean.to_csv(pathFiles + 'facebook_dataset_clean.csv' , quotechar='"', escapechar='\\')
